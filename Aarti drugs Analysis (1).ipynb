# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("aartidrugs.csv")
data
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    AARTIDRUGS     EQ  03-Jan-2022      544.90      550.00      552.30
# 1    AARTIDRUGS     EQ  04-Jan-2022      544.60      546.70      546.70
# 2    AARTIDRUGS     EQ  05-Jan-2022      538.00      537.95      539.00
# 3    AARTIDRUGS     EQ  06-Jan-2022      534.40      534.00      538.50
# 4    AARTIDRUGS     EQ  07-Jan-2022      529.00      529.00      537.05
# ..          ...    ...          ...         ...         ...         ...
# 243  AARTIDRUGS     EQ  26-Dec-2022      455.05      455.50      459.30
# 244  AARTIDRUGS     EQ  27-Dec-2022      444.20      447.00      454.70
# 245  AARTIDRUGS     EQ  28-Dec-2022      446.50      443.00      452.45
# 246  AARTIDRUGS     EQ  29-Dec-2022      448.05      449.95      460.00
# 247  AARTIDRUGS     EQ  30-Dec-2022      451.05      455.00      461.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %%
data.shape
# Out:
# (248, 15)

# %%
data["Prev Close"].describe()
# Out:
# count    248.000000
# mean     456.760685
# std       35.001909
# min      381.100000
# 25%      431.237500
# 50%      454.800000
# 75%      469.687500
# max      544.900000
# Name: Prev Close, dtype: float64

# %%
plt.hist(data["Total Traded Quantity"])
# Out:
# (array([237.,   7.,   1.,   2.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([  23861. ,  342312.3,  660763.6,  979214.9, 1297666.2, 1616117.5,
#         1934568.8, 2253020.1, 2571471.4, 2889922.7, 3208374. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(data["Deliverable Qty"])
plt.plot(data["Total Traded Quantity"])

plt.title("Trade Quantity Analysis")
plt.xlabel("Deliverable Qty")
plt.ylabel("Total Traded Quantity")
plt.show()

# %%
data["High Price"].describe()
# Out:
# count    248.000000
# mean     464.048992
# std       34.851176
# min      390.050000
# 25%      439.850000
# 50%      462.400000
# 75%      480.000000
# max      552.300000
# Name: High Price, dtype: float64

# %%
data["Low Price"].describe()
# Out:
# count    248.000000
# mean     450.856048
# std       34.684977
# min      378.000000
# 25%      425.575000
# 50%      449.900000
# 75%      464.050000
# max      538.500000
# Name: Low Price, dtype: float64

# %%
data["Close Price"].describe()
# Out:
# count    248.000000
# mean     456.418750
# std       34.548658
# min      381.100000
# 25%      431.237500
# 50%      454.800000
# 75%      469.500000
# max      544.600000
# Name: Close Price, dtype: float64

# %%
plt.bar(data["High Price"],data["Total Traded Quantity"])
plt.title("Trade quantity and high price correlation")

plt.xlabel("High Price")
plt.ylabel("Total Traded Quantity")
plt.show()

# %%
plt.bar(data["Low Price"],data["Total Traded Quantity"])
plt.title("Trade quantity and Low price correlation")

plt.xlabel("Low Price")
plt.ylabel("Total Traded Quantity")
plt.show()

# %%
plt.hist(data["No. of Trades"])
plt.show()

# %%
plt.bar(data["Low Price"],data["High Price"])
plt.title("High and Low price correlation")

plt.xlabel("Low Price")
plt.ylabel("High Price")
plt.show()

# %%
plt.bar(data["Open Price"],data["Close Price"])
plt.title("Open and Close price correlation")

plt.xlabel("Open Price")
plt.ylabel("Close Price")
plt.show()

# %%
data["difference"]=data["High Price"] - data["Low Price"]
data["difference"]
# Out:
# 0      13.80
# 1      10.70
# 2       7.50
# 3      10.95
# 4      32.05
#        ...
# 243    18.00
# 244    12.40
# 245    10.35
# 246    14.95
# 247    10.35
# Name: difference, Length: 248, dtype: float64

# %%
data
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    AARTIDRUGS     EQ  03-Jan-2022      544.90      550.00      552.30
# 1    AARTIDRUGS     EQ  04-Jan-2022      544.60      546.70      546.70
# 2    AARTIDRUGS     EQ  05-Jan-2022      538.00      537.95      539.00
# 3    AARTIDRUGS     EQ  06-Jan-2022      534.40      534.00      538.50
# 4    AARTIDRUGS     EQ  07-Jan-2022      529.00      529.00      537.05
# ..          ...    ...          ...         ...         ...         ...
# 243  AARTIDRUGS     EQ  26-Dec-2022      455.05      455.50      459.30
# 244  AARTIDRUGS     EQ  27-Dec-2022      444.20      447.00      454.70
# 245  AARTIDRUGS     EQ  28-Dec-2022      446.50      443.00      452.45
# 246  AARTIDRUGS     EQ  29-Dec-2022      448.05      449.95      460.00
# 247  AARTIDRUGS     EQ  30-Dec-2022      451.05      455.00      461.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %%
data["difference"].describe()
# Out:
# count    248.000000
# mean      13.192944
# std        6.655382
# min        3.750000
# 25%        8.400000
# 50%       11.575000
# 75%       15.850000
# max       41.350000
# Name: difference, dtype: float64

# %%
plt.hist(data["difference"])
plt.title("Price difference between high  and low price")
plt.xlabel("distribution")
plt.ylabel("count")
data["difference"].describe()
# Out:
# count    248.000000
# mean      13.192944
# std        6.655382
# min        3.750000
# 25%        8.400000
# 50%       11.575000
# 75%       15.850000
# max       41.350000
# Name: difference, dtype: float64

# %%
data["diff"]=data["Close Price"]- data["Open Price"]
data["diff"]
# Out:
# 0      -5.40
# 1      -8.70
# 2      -3.55
# 3      -5.00
# 4      -6.10
#        ...
# 243   -11.30
# 244    -0.50
# 245     5.05
# 246     1.10
# 247     5.10
# Name: diff, Length: 248, dtype: float64

# %%
data
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    AARTIDRUGS     EQ  03-Jan-2022      544.90      550.00      552.30
# 1    AARTIDRUGS     EQ  04-Jan-2022      544.60      546.70      546.70
# 2    AARTIDRUGS     EQ  05-Jan-2022      538.00      537.95      539.00
# 3    AARTIDRUGS     EQ  06-Jan-2022      534.40      534.00      538.50
# 4    AARTIDRUGS     EQ  07-Jan-2022      529.00      529.00      537.05
# ..          ...    ...          ...         ...         ...         ...
# 243  AARTIDRUGS     EQ  26-Dec-2022      455.05      455.50      459.30
# 244  AARTIDRUGS     EQ  27-Dec-2022      444.20      447.00      454.70
# 245  AARTIDRUGS     EQ  28-Dec-2022      446.50      443.00      452.45
# 246  AARTIDRUGS     EQ  29-Dec-2022      448.05      449.95      460.00
# 247  AARTIDRUGS     EQ  30-Dec-2022      451.05      455.00      461.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %%
data["diff"].describe()
# Out:
# count    248.000000
# mean      -0.730040
# std        7.927025
# min      -33.600000
# 25%       -5.112500
# 50%       -1.100000
# 75%        3.500000
# max       29.200000
# Name: diff, dtype: float64

# %%
plt.hist(data["diff"])
plt.title("Price difference between close  and open price")
plt.xlabel("distribution")
plt.ylabel("count")
data["diff"].describe()
# Out:
# count    248.000000
# mean      -0.730040
# std        7.927025
# min      -33.600000
# 25%       -5.112500
# 50%       -1.100000
# 75%        3.500000
# max       29.200000
# Name: diff, dtype: float64

# %%
data
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    AARTIDRUGS     EQ  03-Jan-2022      544.90      550.00      552.30
# 1    AARTIDRUGS     EQ  04-Jan-2022      544.60      546.70      546.70
# 2    AARTIDRUGS     EQ  05-Jan-2022      538.00      537.95      539.00
# 3    AARTIDRUGS     EQ  06-Jan-2022      534.40      534.00      538.50
# 4    AARTIDRUGS     EQ  07-Jan-2022      529.00      529.00      537.05
# ..          ...    ...          ...         ...         ...         ...
# 243  AARTIDRUGS     EQ  26-Dec-2022      455.05      455.50      459.30
# 244  AARTIDRUGS     EQ  27-Dec-2022      444.20      447.00      454.70
# 245  AARTIDRUGS     EQ  28-Dec-2022      446.50      443.00      452.45
# 246  AARTIDRUGS     EQ  29-Dec-2022      448.05      449.95      460.00
# 247  AARTIDRUGS     EQ  30-Dec-2022      451.05      455.00      461.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %%
aarti_feb=pd.read_csv("aarti_feb.csv")
aarti_feb
# Out:
#         Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0   AARTIDRUGS     EQ  02-Jan-2023      460.10      462.95      464.00
# 1   AARTIDRUGS     EQ  03-Jan-2023      453.60      450.60      454.40
# 2   AARTIDRUGS     EQ  04-Jan-2023      449.90      448.40      452.65
# 3   AARTIDRUGS     EQ  05-Jan-2023      445.60      443.00      454.00
# 4   AARTIDRUGS     EQ  06-Jan-2023      448.50      448.40      452.90
# 5   AARTIDRUGS     EQ  09-Jan-2023      446.05      450.00      451.00
# 6   AARTIDRUGS     EQ  10-Jan-2023      446.15      446.45      453.00
# 7   AARTIDRUGS     EQ  11-Jan-2023      447.30      449.70      453.80
# 8   AARTIDRUGS     EQ  12-Jan-2023      449.20      449.20      450.15
# 9   AARTIDRUGS     EQ  13-Jan-2023      445.50      446.15      449.95
# 10  AARTIDRUGS     EQ  16-Jan-2023      447.25      446.30      452.40
# 11  AARTIDRUGS     EQ  17-Jan-2023      447.55      448.00      449.20
# ...

# %%
aarti_feb["Close Price"].describe()
# Out:
# count     28.000000
# mean     425.742857
# std       22.646906
# min      380.850000
# 25%      405.675000
# 50%      430.975000
# 75%      446.425000
# max      453.600000
# Name: Close Price, dtype: float64

# %%
aarti_feb["diff"]=aarti_feb["Close Price"]- aarti_feb["Open Price"]
aarti_feb["diff"]
# Out:
# 0     -9.35
# 1     -0.70
# 2     -2.80
# 3      5.50
# 4     -2.35
# 5     -3.85
# 6      0.85
# 7     -0.50
# 8     -3.70
# 9      1.10
# 10     1.25
# 11    -4.30
# 12    -1.90
# 13    -3.90
# 14    -9.75
# 15    -9.70
# 16    -5.45
# 17    -8.25
# 18    -4.85
# 19     3.95
# 20    -4.60
# 21    -1.80
# 22    -7.20
# 23    10.75
# 24   -22.50
# 25    -5.25
# 26    -0.65
# 27   -15.05
# Name: diff, dtype: float64

# %%
aarti_feb
# Out:
#         Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0   AARTIDRUGS     EQ  02-Jan-2023      460.10      462.95      464.00
# 1   AARTIDRUGS     EQ  03-Jan-2023      453.60      450.60      454.40
# 2   AARTIDRUGS     EQ  04-Jan-2023      449.90      448.40      452.65
# 3   AARTIDRUGS     EQ  05-Jan-2023      445.60      443.00      454.00
# 4   AARTIDRUGS     EQ  06-Jan-2023      448.50      448.40      452.90
# 5   AARTIDRUGS     EQ  09-Jan-2023      446.05      450.00      451.00
# 6   AARTIDRUGS     EQ  10-Jan-2023      446.15      446.45      453.00
# 7   AARTIDRUGS     EQ  11-Jan-2023      447.30      449.70      453.80
# 8   AARTIDRUGS     EQ  12-Jan-2023      449.20      449.20      450.15
# 9   AARTIDRUGS     EQ  13-Jan-2023      445.50      446.15      449.95
# 10  AARTIDRUGS     EQ  16-Jan-2023      447.25      446.30      452.40
# 11  AARTIDRUGS     EQ  17-Jan-2023      447.55      448.00      449.20
# ...

# %%
plt.hist(aarti_feb["diff"])
plt.title("Price difference between Close  and Open price")
plt.xlabel("distribution")
plt.ylabel("count")
aarti_feb["diff"].describe()
# Out:
# count    28.00000
# mean     -3.75000
# std       6.34188
# min     -22.50000
# 25%      -5.88750
# 50%      -3.77500
# 75%      -0.61250
# max      10.75000
# Name: diff, dtype: float64

# %%
aarti_feb["difference"]=aarti_feb["High Price"] - aarti_feb["Low Price"]
aarti_feb["difference"]
# Out:
# 0     11.90
# 1      5.40
# 2      8.55
# 3     11.00
# 4      7.90
# 5      6.00
# 6      9.80
# 7      7.05
# 8      5.20
# 9      5.65
# 10     7.35
# 11     6.70
# 12     5.10
# 13     8.35
# 14    18.05
# 15    14.10
# 16     7.50
# 17    13.15
# 18    34.35
# 19    21.45
# 20     9.70
# 21    28.15
# 22    20.70
# 23    23.85
# 24    27.20
# 25    10.20
# 26     9.00
# 27    18.45
# Name: difference, dtype: float64

# %%
plt.hist(aarti_feb["difference"])
plt.title("Price difference between High  and Low price")
plt.xlabel("distribution")
plt.ylabel("count")
aarti_feb["difference"].describe()
# Out:
# count    28.000000
# mean     12.921429
# std       8.005963
# min       5.100000
# 25%       7.275000
# 50%       9.750000
# 75%      18.150000
# max      34.350000
# Name: difference, dtype: float64

# %%
df_datetolowprice=pd.DataFrame({"date" : data["Date"],"Low_price":data["Low Price"]})
df_datetolowprice
# Out:
#             date  Low_price
# 0    03-Jan-2022     538.50
# 1    04-Jan-2022     536.00
# 2    05-Jan-2022     531.50
# 3    06-Jan-2022     527.55
# 4    07-Jan-2022     505.00
# ..           ...        ...
# 243  26-Dec-2022     441.30
# 244  27-Dec-2022     442.30
# 245  28-Dec-2022     442.10
# 246  29-Dec-2022     445.05
# 247  30-Dec-2022     450.65
#
# [248 rows x 2 columns]

# %%
df_datetolowprice.plot("date","Low_price")
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_datetolowprice.describe()
# Out:
#         Low_price
# count  248.000000
# mean   450.856048
# std     34.684977
# min    378.000000
# 25%    425.575000
# 50%    449.900000
# 75%    464.050000
# max    538.500000

# %%
data["Average Price"].max()
# Out:
# 544.57

# %%
data["Average Price"].min()
# Out:
# 383.65

# %%
data["Average Price"].mean()
# Out:
# 457.4606048387097

# %%
data["Average Price"].mode()
# Out:
# 0    423.76
# 1    457.51
# 2    462.54
# Name: Average Price, dtype: float64

# %%
data["Average Price"].median()
# Out:
# 455.525

# %%
plt.bar(data["Average Price"],data["Date"])
# Out:
# <BarContainer object of 248 artists>

# %%
plt.bar(data["Average Price"],data["No. of Trades"])
# Out:
# <BarContainer object of 248 artists>

# %%
plt.bar(data["Deliverable Qty"].sum(),data["No. of Trades"])
# Out:
# <BarContainer object of 248 artists>

# %%
data["Date"]=pd.to_datetime(data["Date"])
data["Date"].head()
# Out:
# 0   2022-01-03
# 1   2022-01-04
# 2   2022-01-05
# 3   2022-01-06
# 4   2022-01-07
# Name: Date, dtype: datetime64[ns]

# %%
data.head()
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0  AARTIDRUGS     EQ 2022-01-03       544.9      550.00      552.30
# 1  AARTIDRUGS     EQ 2022-01-04       544.6      546.70      546.70
# 2  AARTIDRUGS     EQ 2022-01-05       538.0      537.95      539.00
# 3  AARTIDRUGS     EQ 2022-01-06       534.4      534.00      538.50
# 4  AARTIDRUGS     EQ 2022-01-07       529.0      529.00      537.05
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     538.50       544.0        544.6         544.57                 152309
# 1     536.00       536.9        538.0         539.35                  86580
# 2     531.50       535.0        534.4         535.37                 131752
# 3     527.55       530.5        529.0         532.22                 115313
# 4     505.00       524.4        522.9         525.43                 188493
#
#       Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
data["Date"].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 243    12
# 244    12
# 245    12
# 246    12
# 247    12
# Name: Date, Length: 248, dtype: int64

# %%
data["month"]=data["Date"].dt.month
data["month"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 243    12
# 244    12
# 245    12
# 246    12
# 247    12
# Name: month, Length: 248, dtype: int64

# %%
data.head()
# Out:
#        Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0  AARTIDRUGS     EQ 2022-01-03       544.9      550.00      552.30
# 1  AARTIDRUGS     EQ 2022-01-04       544.6      546.70      546.70
# 2  AARTIDRUGS     EQ 2022-01-05       538.0      537.95      539.00
# 3  AARTIDRUGS     EQ 2022-01-06       534.4      534.00      538.50
# 4  AARTIDRUGS     EQ 2022-01-07       529.0      529.00      537.05
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     538.50       544.0        544.6         544.57                 152309
# 1     536.00       536.9        538.0         539.35                  86580
# 2     531.50       535.0        534.4         535.37                 131752
# 3     527.55       530.5        529.0         532.22                 115313
# 4     505.00       524.4        522.9         525.43                 188493
#
#       Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
data["Monthly_mean"]= data.groupby("month")["Close Price"].aggregate("mean")
night=data["Monthly_mean"]

# %%
data
# Out:
#          Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0    AARTIDRUGS     EQ 2022-01-03      544.90      550.00      552.30
# 1    AARTIDRUGS     EQ 2022-01-04      544.60      546.70      546.70
# 2    AARTIDRUGS     EQ 2022-01-05      538.00      537.95      539.00
# 3    AARTIDRUGS     EQ 2022-01-06      534.40      534.00      538.50
# 4    AARTIDRUGS     EQ 2022-01-07      529.00      529.00      537.05
# ..          ...    ...        ...         ...         ...         ...
# 243  AARTIDRUGS     EQ 2022-12-26      455.05      455.50      459.30
# 244  AARTIDRUGS     EQ 2022-12-27      444.20      447.00      454.70
# 245  AARTIDRUGS     EQ 2022-12-28      446.50      443.00      452.45
# 246  AARTIDRUGS     EQ 2022-12-29      448.05      449.95      460.00
# 247  AARTIDRUGS     EQ 2022-12-30      451.05      455.00      461.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %%
data.shape
# Out:
# (248, 19)

# %%
data.isnull().sum()
# Out:
# Symbol                      0
# Series                      0
# Date                        0
# Prev Close                  0
# Open Price                  0
# High Price                  0
# Low Price                   0
# Last Price                  0
# Close Price                 0
# Average Price               0
# Total Traded Quantity       0
# Turnover                    0
# No. of Trades               0
# Deliverable Qty             0
# % Dly Qt to Traded Qty      0
# difference                  0
# diff                        0
# month                       0
# Monthly_mean              236
# dtype: int64

# %%
night.plot(kind='month', ax='Monthly_mean')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 night.plot(kind='month', ax='Monthly_mean')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_core.py:905, in PlotAccessor.__call__(self, *args, **kwargs)
#     902     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     904 if kind not in self._all_kinds:
# --> 905     raise ValueError(f"{kind} is not a valid plot kind")
#     907 # The original data structured can be transformed before passed to the
#     908 # backend. For example, for DataFrame is common to set the index as the
#     909 # `x` parameter, and return a Series with the parameter `y` as values.
#     910 data = self._parent.copy()
#
# ValueError: month is not a valid plot kind

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
# tips=sns.load_dataset("aartidrugs.csv")

# %%
data["Close Price"]=float(data["Close Price"])

# %%
print(sns.get_dataset_names())

# %%
data.dtypes

# %%
sns.pairplot(data)
